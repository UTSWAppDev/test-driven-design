# %% [markdown]
# # TDD Exercise: Build a Calculator with Python's unittest
#
# ## Learning Objectives
# By the end of this exercise, you will:
# - Practice the full Test-Driven Design workflow on your own
# - Define placeholder functions before implementation
# - Write unit tests for calculator behavior
# - Run tests against placeholders and observe failures
# - Replace placeholders with real logic and verify all tests pass
#
# **Important**: This notebook is intentionally scaffolded. You will complete each step yourself.

# %% [markdown]
# ## 1. Import Required Libraries
# Run the cell below first.

# %%
import unittest

print("✓ Libraries imported. Step 1 complete.")

# %% [markdown]
# ## 2. Define the Problem (Theory + Design)
#
# You are building a simple calculator with these operations:
# - `add(a, b)`
# - `subtract(a, b)`
# - `multiply(a, b)`
# - `divide(a, b)`
#
# ### Your task in this step
# In the next code cell, document:
# 1. The purpose of each function
# 2. The ins and outs (parameter types and return type)
#
# Use comments to write your function contracts before coding.

# %%
# STEP 2: Write your function contracts below.
# Example style:
# Purpose: add() returns the sum of two numbers.
# add: (float, float) -> float

# TODO: Document the purpose and ins/outs for add()
# TODO: Document the purpose and ins/outs for subtract()
# TODO: Document the purpose and ins/outs for multiply()
# TODO: Document the purpose and ins/outs for divide()

print("✓ Step 2 notes drafted (update TODOs with your own contracts).")

# %% [markdown]
# ## 3. Create Placeholder Functions
#
# Write placeholder versions of all calculator functions so your test suite has something to call.
#
# Use temporary return values first. These should be replaced later with real logic.

# %%
# STEP 3: Placeholder functions

def add(a, b):
    # TODO: placeholder return value

def subtract(a, b):
    # TODO: placeholder return value

def multiply(a, b):
    # TODO: placeholder return value

def divide(a, b):
    # TODO: placeholder return value

print("✓ Placeholder functions created. Step 3 complete.")

# %% [markdown]
# ## 4. Build the Tests
#
# Now write tests for each calculator operation.
#
# ### Required tests
# At minimum, include tests for:
# - `add(2, 3) == 5`
# - `subtract(10, 4) == 6`
# - `multiply(3, 7) == 21`
# - `divide(8, 2) == 4`
#
# ### Recommended edge cases
# - Negative numbers
# - Zero values
# - Division by zero (decide behavior and test it)

# %%
# STEP 4: Write your tests

class TestCalculator(unittest.TestCase):
    """Tests for calculator functions"""

    def test_add(self):
        # TODO: Replace with your own complete test set
        # HINT: This should look something like: self.assertEqual(...) but with your own test cases instead of ...

    def test_subtract(self):
        # TODO: Replace with your own complete test set

    def test_multiply(self):
        # TODO: Replace with your own complete test set

    def test_divide(self):
        # TODO: Replace with your own complete test set

    # TODO (recommended): add edge-case tests

print("✓ Test class created. Step 4 complete (expand tests before moving on).")

# %% [markdown]
# ## 5. Run Tests Against Placeholder Functions
#
# Run the tests now. Because your functions are placeholders, failures are expected.
#
# If tests fail, that means your tests are correctly detecting missing behavior.

# %%
# STEP 5: Execute tests (expected: some failures with placeholder functions)
suite = unittest.TestLoader().loadTestsFromTestCase(TestCalculator)
runner = unittest.TextTestRunner(verbosity=2)
result = runner.run(suite)

print(f"\n{'='*50}")
print(f"Tests run: {result.testsRun}")
print(f"Successes: {result.testsRun - len(result.failures) - len(result.errors)}")
print(f"Failures: {len(result.failures)}")
print(f"Errors: {len(result.errors)}")
print(f"{'='*50}")

print("✓ Step 5 complete. Review failing tests, then implement the real functions.")

# %% [markdown]
# ## 6. Replace Placeholders with Real Implementations
#
# Now rewrite each function with correct calculator logic so your tests can pass.
#
# If you decided on behavior for division by zero, implement that behavior now.

# %%
# STEP 6: Replace placeholders with real logic

def add(a, b):
    # TODO: implement the real thing

def subtract(a, b):
    # TODO: implement the real thing

def multiply(a, b):
    # TODO: implement the real thing

def divide(a, b):
    # TODO: implement (including division-by-zero behavior)


print("✓ Step 6 scaffold ready. Replace all TODOs with working implementations.")

# %% [markdown]
# ## 7. Run Tests Again and Confirm Green
#
# Re-run the same test runner after implementing your functions.
# All tests should pass when your implementation is complete.

# %%
# STEP 7: Execute tests again (expected: all pass after implementation)
suite = unittest.TestLoader().loadTestsFromTestCase(TestCalculator)
runner = unittest.TextTestRunner(verbosity=2)
result = runner.run(suite)

print(f"\n{'='*50}")
print(f"Tests run: {result.testsRun}")
print(f"Successes: {result.testsRun - len(result.failures) - len(result.errors)}")
print(f"Failures: {len(result.failures)}")
print(f"Errors: {len(result.errors)}")
print(f"{'='*50}")

if len(result.failures) == 0 and len(result.errors) == 0:
    print("🎉 Great work! You completed the full TDD cycle.")
else:
    print("Keep iterating: update implementation/tests and run again.")

# %% [markdown]
# ## Reflection
#
# Before you finish, answer these questions in your notes:
# 1. Which tests failed first, and why?
# 2. How did failing tests help guide your implementation?
# 3. What edge case was most important for calculator correctness?
# 4. How would you extend this calculator in another TDD cycle?
